# %% [markdown]
# pandas (data manupuation / data prep)
#
# pandas seres - one d array
# pandas datframe - n*n matrix

# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 11.0 MB/s  0:00:00eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
l = [1,2,3,4,5,6]
pds = pd.Series(l , index = [10,20,30,40,50,60])
pds[10]
# Out:
# np.int64(1)

# %%
pds
# Out:
# 10    1
# 20    2
# 30    3
# 40    4
# 50    5
# 60    6
# dtype: int64

# %%
marks = {
    "phy" : [93,45,65,44],
    "chem" : [93,45,65,44],
    "maths" : [93,45,65,44],
    "bio" : [93,45,65,44]
}

# %%
marks
# Out:
# {'phy': [93, 45, 65, 44],
#  'chem': [93, 45, 65, 44],
#  'maths': [93, 45, 65, 44],
#  'bio': [93, 45, 65, 44]}

# %%
df = pd.DataFrame(marks , index = ["payal" , "akash" , "pratham" , "pratibha"])

# %%
df
# Out:
#           phy  chem  maths  bio
# payal      93    93     93   93
# akash      45    45     45   45
# pratham    65    65     65   65
# pratibha   44    44     44   44

# %%
l = [[10,20,30],[40,50,60]]

# %%
ldf = pd.DataFrame(l , columns = ["a","b","c"] , dtype = 'f')

# %%
ldf
# Out:
#       a     b     c
# 0  10.0  20.0  30.0
# 1  40.0  50.0  60.0

# %%
ldf.shape
# Out:
# (2, 3)

# %%
df.shape
# Out:
# (4, 4)

# %%
df.head(2)
# Out:
#        phy  chem  maths  bio
# payal   93    93     93   93
# akash   45    45     45   45

# %%
df.tail(2)
# Out:
#           phy  chem  maths  bio
# pratham    65    65     65   65
# pratibha   44    44     44   44

# %%
na = df.values

# %%
na
# Out:
# array([[93, 93, 93, 93],
#        [45, 45, 45, 45],
#        [65, 65, 65, 65],
#        [44, 44, 44, 44]])

# %%
df
# Out:
#           phy  chem  maths  bio
# payal      93    93     93   93
# akash      45    45     45   45
# pratham    65    65     65   65
# pratibha   44    44     44   44

# %%
df.columns
# Out:
# Index(['phy', 'chem', 'maths', 'bio'], dtype='object')

# %%
na[2][1]
# Out:
# np.int64(65)

# %%
df
# Out:
#           phy  chem  maths  bio
# payal      93    93     93   93
# akash      45    45     45   45
# pratham    65    65     65   65
# pratibha   44    44     44   44

# %%
df[["phy","chem"]]
# Out:
#           phy  chem
# payal      93    93
# akash      45    45
# pratham    65    65
# pratibha   44    44

# %%
df.loc[["payal", "akash"], ["phy","bio"]]
# Out:
#        phy  bio
# payal   93   93
# akash   45   45

# %%
df.loc[["akash"], ["phy" ]]
# Out:
#        phy
# akash   45

# %%
df.iloc[1,1]
# Out:
# np.int64(45)

# %%
df.iloc[[0,2],[0,2]]
# Out:
#          phy  maths
# payal     93     93
# pratham   65     65

# %%
df.iloc[0:2:3 , 0:2:3]
# Out:
#        phy
# payal   93

# %%
df.to_csv("marks.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, payal to pratibha
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   phy     4 non-null      int64
#  1   chem    4 non-null      int64
#  2   maths   4 non-null      int64
#  3   bio     4 non-null      int64
# dtypes: int64(4)
# memory usage: 332.0+ bytes

# %%
df
# Out:
#           phy  chem  maths  bio
# payal      93    93     93   93
# akash      45    45     45   45
# pratham    65    65     65   65
# pratibha   44    44     44   44

# %%
df.iloc[[3,2,1],[0,1]]
# Out:
#           phy  chem
# pratibha   44    44
# pratham    65    65
# akash      45    45

# %%
df[df['chem']<90]
# Out:
#           phy  chem  maths  bio
# akash      45    45     45   45
# pratham    65    65     65   65
# pratibha   44    44     44   44

# %%
df[df['maths'] == 45]
# Out:
#           phy  chem  maths  bio
# payal      93    93     45   93
# akash      45    45     45   45
# pratham    65    65     45   65
# pratibha   44    44     45   44
