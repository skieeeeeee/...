# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return 2*x**2 + 3*x + 5

# %%
X = np.linspace(-4,3,1000)
y = f(X)

# %%
plt.plot(X,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def det_fx(x):
    return 4*x + 3

# %%
alpha = 0.50
x = 2
epochs = 10
xs = [x]
for e in range(epochs):
    x = x - alpha*det_fx(x)
    xs.append(x)
x
# Out:
# 2.0

# %%
plt.plot(X,y)
plt.plot(xs, f(np.array(xs)), c = 'r') 
plt.show()

# %%
X = np.array([2,3,6,7])
y = np.array([3,2,7,6])

w0,w1 = 1,1
alpha = 0.1
ypred = w1*x + w0

# %%
plt.scatter(x,y)
plt.plot(x,ypred , c = 'r')
plt.show()

# %%
ypred = w1*x+w0
w1 = w1 - alpha*np.mean((ypred-y)*x)
w0 = w0 - alpha*np.mean(ypred-y)

# %%
w1,w0
# Out:
# (np.float64(1.815512500000001), np.float64(1.3082625000000003))

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[130], line 3
#       1 w = [1]
#       2 w0 = 1
# ----> 3 ypred = hypothesis(X,w,w0)
#
# Cell In[129], line 5, in hypothesis(X, w, w0)
#       3 for i in  range(X.shape[0]):
#       4     p = w0
# ----> 5     for j in range (X.shape[1]):
#       6         p += X[i][j]*w[j]
#       7     ypred.append(p)
#
# IndexError: tuple index out of range
