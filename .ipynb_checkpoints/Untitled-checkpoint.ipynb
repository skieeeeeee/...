# %%
for i in filter (lamda x : 2*i,10):
print(i)
# Out:
#   Cell In[1], line 1
#     for i in filter (lamda x : 2*i,10):
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
range(1,10)
# Out:
# range(1, 10)

# %%
def myrange(start=0,stop=10):
# Out:
#   Cell In[3], line 1
#     def myrange(start=0,stop=10):
#                                  ^
# _IncompleteInputError: incomplete input

# %%
def myrange(start=0,stop=10):
    i=start
    while<stop:
    print(i)
i+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 5
#       3     while i<stop:
#       4         print(i)
# ----> 5 i+=1
#
# NameError: name 'i' is not defined

# %%
def myrange(start=0,stop=10):
    i=start
    while i < stop:
        print(i)
        i+=1

# %%
itr = myrange(1,10)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
next(itr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 next(itr)
#
# TypeError: 'NoneType' object is not an iterator

# %%
l = [(1,10),(5,200),(3,48),(2,150),(4,120)]

# %%
import Mymodule as mm
# Out:
# HELLO WELCOME TO MY MODULE

# %%
mm.fn()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mm.fn()
#
# NameError: name 'mm' is not defined
