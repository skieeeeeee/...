# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon.csv" , index_col = "Name")

# %%
df
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
# selection by column

# %%
df[["Name","HP" ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df[["Name","HP" ]]
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
# ...

# %%
#selection by row

# %%
df.loc[(2,5,20,50,100,9) , ["Name" ,"HP", "Type 1"] ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df.loc[(2,5,20,50,100,9) , ["Name" ,"HP", "Type 1"] ]
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages/pandas/core/indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages/pandas/core/indexing.py:1376, in _LocIndexer._getitem_tuple(self, tup)
#    1374 # ugly hack for GH #836
#    1375 if self._multi_take_opportunity(tup):
# -> 1376     return self._multi_take(tup)
# ...

# %%
df.iloc

# %%
df.iloc[0:11]
# Out:
#                            # Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                  1  Grass  Poison    318  45      49       49
# Ivysaur                    2  Grass  Poison    405  60      62       63
# Venusaur                   3  Grass  Poison    525  80      82       83
# VenusaurMega Venusaur      3  Grass  Poison    625  80     100      123
# Charmander                 4   Fire     NaN    309  39      52       43
# Charmeleon                 5   Fire     NaN    405  58      64       58
# Charizard                  6   Fire  Flying    534  78      84       78
# CharizardMega Charizard X  6   Fire  Dragon    634  78     130      111
# CharizardMega Charizard Y  6   Fire  Flying    634  78     104       78
# Squirtle                   7  Water     NaN    314  44      48       65
# Wartortle                  8  Water     NaN    405  59      63       80
#
#                            Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pokemon = input("enter a pokemon name : ")
try :
    print(df.loc[pokemon])
except keyerror :
    (f"{pokemon} not found ")
# Out:
# enter a pokemon name :  Charizard
# #                  6
# Type 1          Fire
# Type 2        Flying
# Total            534
# HP                78
# Attack            84
# Defense           78
# Sp. Atk          109
# Sp. Def           85
# Speed            100
# Generation         1
# Legendary      False
# Name: Charizard, dtype: object

# %%
#filtering

# %%
Grass_pokemons = df[df["Type 1"] == "Grass"]

# %%
Grass_pokemons
# Out:
#                          # Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# Bulbasaur                1  Grass    Poison    318   45      49       49
# Ivysaur                  2  Grass    Poison    405   60      62       63
# Venusaur                 3  Grass    Poison    525   80      82       83
# VenusaurMega Venusaur    3  Grass    Poison    625   80     100      123
# Oddish                  43  Grass    Poison    320   45      50       55
# ...                    ...    ...       ...    ...  ...     ...      ...
# Chespin                650  Grass       NaN    313   56      61       65
# Quilladin              651  Grass       NaN    405   61      78       95
# Chesnaught             652  Grass  Fighting    530   88     107      122
# Skiddo                 672  Grass       NaN    350   66      65       48
# Gogoat                 673  Grass       NaN    531  123     100       62
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
legendary_pokemon = df[df["Legendary"] == 1]

# %%
legendary_pokemon
# Out:
#                        #    Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# Articuno             144       Ice    Flying    580   90      85      100
# Zapdos               145  Electric    Flying    580   90      90       85
# Moltres              146      Fire    Flying    580   90     100       90
# Mewtwo               150   Psychic       NaN    680  106     110       90
# MewtwoMega Mewtwo X  150   Psychic  Fighting    780  106     190      100
# ...                  ...       ...       ...    ...  ...     ...      ...
# Diancie              719      Rock     Fairy    600   50     100      150
# DiancieMega Diancie  719      Rock     Fairy    700   50     160      110
# HoopaHoopa Confined  720   Psychic     Ghost    600   80     110       60
# HoopaHoopa Unbound   720   Psychic      Dark    680   80     160       60
# Volcanion            721      Fire     Water    600   80     110      120
#
#                      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
Grass_Flying = df[(df["Type 1"] =="Grass") & (df["Type 2"] == "Flying")]
Grass_Flying
# Out:
#                     # Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Hoppip            187  Grass  Flying    250   35      35       40       35
# Skiploom          188  Grass  Flying    340   55      45       50       45
# Jumpluff          189  Grass  Flying    460   75      55       70       55
# Tropius           357  Grass  Flying    460   99      68       83       72
# ShayminSky Forme  492  Grass  Flying    600  100     103       75      120
#
#                   Sp. Def  Speed  Generation  Legendary
# Name
# Hoppip                 55     50           2      False
# Skiploom               65     80           2      False
# Jumpluff               95    110           2      False
# Tropius                87     51           3      False
# ShayminSky Forme       75    127           4       True

# %%
Fire_Flying = df[(df["Type 1"] == "Fire") & (df["Type 2"] == "Flying")]
Fire_Flying
# Out:
#                              # Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Charizard                    6   Fire  Flying    534   78      84       78
# CharizardMega Charizard Y    6   Fire  Flying    634   78     104       78
# Moltres                    146   Fire  Flying    580   90     100       90
# Ho-oh                      250   Fire  Flying    680  106     130       90
# Fletchinder                662   Fire  Flying    382   62      73       55
# Talonflame                 663   Fire  Flying    499   78      81       71
#
#                            Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Charizard                      109       85    100           1      False
# CharizardMega Charizard Y      159      115    100           1      False
# Moltres                        125       85     90           1       True
# Ho-oh                          110      154     90           2       True
# ...

# %%
   # Aggregate function
#these all applied in the whole dataframe
df.mean(numeric_only=True)
# Out:
# #             362.81375
# Total         435.10250
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
df.sum(numeric_only=True)
# Out:
# #             290251
# Total         348082
# HP             55407
# Attack         63201
# Defense        59074
# Sp. Atk        58256
# Sp. Def        57522
# Speed          54622
# Generation      2659
# Legendary         65
# dtype: int64

# %%
df.min(numeric_only=True)
# Out:
# #                 1
# Total           180
# HP                1
# Attack            5
# Defense           5
# Sp. Atk          10
# Sp. Def          20
# Speed             5
# Generation        1
# Legendary     False
# dtype: object

# %%
df.max(numeric_only=True)
# Out:
# #              721
# Total          780
# HP             255
# Attack         190
# Defense        230
# Sp. Atk        194
# Sp. Def        230
# Speed          180
# Generation       6
# Legendary     True
# dtype: object

# %%
df.count()
# Out:
# #             800
# Type 1        800
# Type 2        414
# Total         800
# HP            800
# Attack        800
# Defense       800
# Sp. Atk       800
# Sp. Def       800
# Speed         800
# Generation    800
# Legendary     800
# dtype: int64

# %%
#Group data 
group = df.groupby("Type 2")

# %%
group

# %%
group["HP"].sum()
# Out:
# Type 2
# Bug          160
# Dark        1511
# Dragon      1479
# Electric     529
# Fairy       1479
# Fighting    2066
# Fire         855
# Flying      6925
# Ghost        828
# Grass       1566
# Ground      2703
# Ice         1260
# Normal       254
# Poison      1998
# Psychic     2383
# Rock         953
# Steel       1422
# Water        878
# Name: HP, dtype: int64

# %%
# Data removing 
df
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
#drop irrelevent columns 
df = df.drop(columns = ["Legendary" , "#"])
df
# Out:
#                         Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charmander                Fire     NaN    309  39      52       43       60
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
#                        Sp. Def  Speed  Generation
# ...

# %%
#handle missing data 
df = df.dropna(subset = ["Type 2"])
df
# Out:
#                         Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charizard                 Fire  Flying    534  78      84       78      109
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
#                        Sp. Def  Speed  Generation
# ...

# %%
df = df.fillna({"Type 2": "None" })

# %%
 df.to_string()
# Out:
# "                             Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation\nName                                                                                                           \nBulbasaur                     Grass    Poison    318   45      49       49       65       65     45           1\nIvysaur                       Grass    Poison    405   60      62       63       80       80     60           1\nVenusaur                      Grass    Poison    525   80      82       83      100      100     80           1\nVenusaurMega Venusaur         Grass    Poison    625   80     100      123      122      120     80           1\nCharmander                     Fire      None    309   39      52       43       60       50     65           1\nCharmeleon                     Fire      None    405   58      64       58       80       65     80           1\nCharizard                      Fire    Flying    534   78      84       78      109       85 
# ...
