# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (7.5 kB)
# Downloading mysql_connector_python-9.5.0-cp313-cp313-macosx_14_0_arm64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 11.3 MB/s  0:00:01 11.6 MB/s eta 0:00:01
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector 
import pandas as pd

# %%
connection = mysql.connector.connect(user = 'root' , password = 'Bhandari@8255')

# %%
cursor = connection.cursor()

# %%
cursor.execute('show databases')

# %%
for ele in cursor :
    print(ele)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('school',)
# ('sys',)

# %%
cursor.execute('use school')

# %%
for ele in cursor :
    print(ele)

# %%
cursor.execute('show tables ')

# %%
for ele in cursor :
    print(ele)
