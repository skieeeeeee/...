# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
cv2.__version__
# Out:
# '4.11.0'

# %%
img = cv2.imread('dog.png')
# our cv2 model se images as brg to so to see real color you have to convert this in rgb 
#there are two ways by numpy operations or by cv2 operations
new_img = img[:,:,::-1]
#new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

#to change color to gray we can do is 
#gray = cv2.cvtColor(img, cv2.COLOR_BRG2GRAY) WTHHHHHHHHHHHHH
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
print(img.shape)
# Out:
# (360, 360, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(new_img)
plt.show()

# %%
plt.imshow(gray,cmap = 'gray')
plt.show()
